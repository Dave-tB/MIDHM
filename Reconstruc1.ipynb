# %%
# %pylab inline
# %load_ext autoreload
# %autoreload 2
# Out:
# %pylab is deprecated, use %matplotlib inline and import the required libraries.
# Populating the interactive namespace from numpy and matplotlib

# %%
import midhm as M

# %%
h = M.Util.load('data/obj1.tif')

# %%
h_norm = M.Util.normalize(h)

# %%
t, amp, phi, absorptn, UnimgH, UnimgH2 = M.Reconstructor.reconstruct(h_norm)
# Out:
# /home/d/Projects/MIDHM/midhm/reconstructor.py:137: RuntimeWarning: divide by zero encountered in true_divide
#   dctPhi = dctRho / 2 / (np.cos(np.pi*I/M) + np.cos(np.pi*J/N) - 2)

# %%
# you can also pass in different parameters as below
t, amp, phi, absorptn, UnimgH, UnimgH2 = M.Reconstructor.reconstruct(h_norm,
                                                                    lambda_=488e-9, 
                                                                    dx=1.12e-6,
                                                                    dy=1.12e-6,
                                                                    z=4e-2,
                                                                    dmax=7e-3)

# %%
imshow(absorptn)

# %%
imshow(amp)

# %%
imshow(phi)

# %%
imshow(UnimgH)

# %%
imshow(UnimgH2[0]) ### this uses the method from the paper but seems broken
